# %%
from ta_agent import run_ta_agent


ta_output = run_ta_agent()
print(f"\n{'=' * 60}")
print("TA STRUCTURED OUTPUT")
print(f"{'=' * 60}")
print(f"  Direction:   {ta_output.direction}")
print(f"  Price:       ${ta_output.current_price:,.0f}")
print(f"  Target:      ${ta_output.target_low:,.0f} – ${ta_output.target_high:,.0f}")
print(f"  Support:     ${ta_output.key_support:,.0f}")
print(f"  Resistance:  ${ta_output.key_resistance:,.0f}")
print(f"  Confidence:  {ta_output.confidence:.0%}")

print(f"\n{'=' * 60}")

print(f"TA REPORT:  {ta_output.report}")
# Out:
# ============================================================
# BTC/USDT Technical Analysis Agent
# ============================================================
#
# [SQL QUERY]
# SELECT timestamp, close, rsi_14 FROM btc_ohlcv WHERE rsi_14 < 35 OR rsi_14 > 65 ORDER BY timestamp DESC LIMIT 50
#
#
# [SQL QUERY]
# SELECT * FROM btc_ohlcv ORDER BY timestamp DESC LIMIT 100
#
#
# [SQL QUERY]
# SELECT timestamp, macd, macd_signal, macd_hist FROM btc_ohlcv ORDER BY timestamp DESC LIMIT 100
#
#
# [SQL QUERY]
# SELECT timestamp, close, bb_lower, bb_upper FROM btc_ohlcv WHERE close < bb_lower OR close > bb_upper ORDER BY timestamp DESC LIMIT 50
#
#
# [SQL QUERY]
# SELECT timestamp, close, ema_50 FROM btc_ohlcv ORDER BY timestamp DESC LIMIT 100
#
#
# [SQL QUERY]
# SELECT timestamp, close, volume FROM btc_ohlcv ORDER BY timestamp DESC LIMIT 100
#
#
# ============================================================
# TA STRUCTURED OUTPUT
# ============================================================
#   Direction:   BULLISH
#   Price:       $74,639
#   Target:      $75,000 – $76,000
#   Support:     $74,300
#   Resistance:  $74,917
#   Confidence:  75%
#
# ============================================================
# TA REPORT:  ---
# ## BTC/USDT Technical Analysis Report
#
# **Current Price:** $74,639.31
#
# ### Market Condition
# BTC/USDT is currently trading strongly above its 50-period EMA (around $74,300), indicating a bullish macro trend on the 5-minute timeframe. The price has recently touched the upper Bollinger Band multiple times, signifying strong bullish momentum but also potential short-term overextension.
#
# ### Bullish Signals
# - The MACD histogram is positive and rising, confirming upward momentum with MACD well above its signal line.
# - RSI values have recently been frequently above 65, peaking beyond 80, indicating strong buying pressure.
# - Price sustained above EMA(50) and the Bollinger upper band around $74,700 - $74,900 region shows strength.
#
# ### Bearish Signals
# - RSI readings indicate overbought conditions, with spikes above 80, suggesting a risk of near-term pullback.
# - Price occasionally tests the upper Bollinger Band which might attract profit-taking.
# - Volume spikes around $74,900 were followed by lower volume at the latest candles, which could hint at some seller absorption.
#
# ### Volume Analysis
# Volume has been relatively robust during price advances, especially on candles pushing price above $74,700. Some volume tapering is visible in the last few candles despite continued price strength, a nuance to watch for potential divergence.
#
# ### 1-Week Price Target
# **Target:** $75,000 – $76,000
# **Reasoning:** With the strong bullish momentum confirmed by MACD and consistent support above EMA(50), the short-term trend points to continuation upward. Resistance at the recent highs near $74,900 may be broken on sustained volume and momentum, targeting the next psychological resistance zone near $76,000.
# **Confidence:** Medium-High due to strong technical signals but tempered by the overbought RSI and near-term volume dynamics.
# ---
